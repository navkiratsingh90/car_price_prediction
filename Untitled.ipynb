# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")

# %%
df  = pd.read_csv('House_Rent_Dataset.csv')
# df['Posted On'] = pd.to_datetime(df['Posted On'])

# df['Posted_Year'] = df['Posted On'].dt.year
# df['Posted_Month'] = df['Posted On'].dt.month
df.drop(columns='Posted On', inplace=True)
# df.drop(columns='Floor', inplace=True)

# %%
df
# Out:
#       BHK   Rent  Size            Floor    Area Type  \
# 0       2  10000  1100  Ground out of 2   Super Area
# 1       2  20000   800       1 out of 3   Super Area
# 2       2  17000  1000       1 out of 3   Super Area
# 3       2  10000   800       1 out of 2   Super Area
# 4       2   7500   850       1 out of 2  Carpet Area
# ...   ...    ...   ...              ...          ...
# 4741    2  15000  1000       3 out of 5  Carpet Area
# 4742    3  29000  2000       1 out of 4   Super Area
# 4743    3  35000  1750       3 out of 5  Carpet Area
# 4744    3  45000  1500     23 out of 34  Carpet Area
# 4745    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# 1     Phool Bagan, Kankurgachi    Kolkata    Semi-Furnished  Bachelors/Family
# 2      Salt Lake City Sector 2    Kolkata    Semi-Furnished  Bachelors/Family
# ...

# %%
df.head()
# Out:
#    BHK   Rent  Size            Floor    Area Type             Area Locality  \
# 0    2  10000  1100  Ground out of 2   Super Area                    Bandel
# 1    2  20000   800       1 out of 3   Super Area  Phool Bagan, Kankurgachi
# 2    2  17000  1000       1 out of 3   Super Area   Salt Lake City Sector 2
# 3    2  10000   800       1 out of 2   Super Area               Dumdum Park
# 4    2   7500   850       1 out of 2  Carpet Area             South Dum Dum
#
#       City Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# 0  Kolkata       Unfurnished  Bachelors/Family         2    Contact Owner
# 1  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 2  Kolkata    Semi-Furnished  Bachelors/Family         1    Contact Owner
# 3  Kolkata       Unfurnished  Bachelors/Family         1    Contact Owner
# 4  Kolkata       Unfurnished         Bachelors         1    Contact Owner

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BHK                4746 non-null   int64
#  1   Rent               4746 non-null   int64
#  2   Size               4746 non-null   int64
#  3   Floor              4746 non-null   object
#  4   Area Type          4746 non-null   object
#  5   Area Locality      4746 non-null   object
#  6   City               4746 non-null   object
#  7   Furnishing Status  4746 non-null   object
#  8   Tenant Preferred   4746 non-null   object
#  9   Bathroom           4746 non-null   int64
#  10  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 408.0+ KB

# %%
df.isnull().sum()
# Out:
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
df.shape
# Out:
# (4746, 11)

# %%
df.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'Floor', 'Area Type', 'Area Locality', 'City',
#        'Furnishing Status', 'Tenant Preferred', 'Bathroom',
#        'Point of Contact'],
#       dtype='object')

# %%
plt.figure()
plt.hist(df['City'],bins = 10)
plt.show()

# %%
plt.figure()
sns.boxplot(x = 'Rent', data = df)
# sns.histplot(df['Rent'], kde = False)
plt.show()

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
x = df.drop('Rent',axis = 1)
y = df['Rent']

# %%
x
# Out:
#       BHK  Size            Floor    Area Type             Area Locality  \
# 0       2  1100  Ground out of 2   Super Area                    Bandel
# 1       2   800       1 out of 3   Super Area  Phool Bagan, Kankurgachi
# 2       2  1000       1 out of 3   Super Area   Salt Lake City Sector 2
# 3       2   800       1 out of 2   Super Area               Dumdum Park
# 4       2   850       1 out of 2  Carpet Area             South Dum Dum
# ...   ...   ...              ...          ...                       ...
# 4741    2  1000       3 out of 5  Carpet Area              Bandam Kommu
# 4742    3  2000       1 out of 4   Super Area      Manikonda, Hyderabad
# 4743    3  1750       3 out of 5  Carpet Area      Himayath Nagar, NH 7
# 4744    3  1500     23 out of 34  Carpet Area                Gachibowli
# 4745    2  1000       4 out of 5  Carpet Area           Suchitra Circle
#
#            City Furnishing Status  Tenant Preferred  Bathroom Point of Contact
# ...

# %%
y
# Out:
# 0       10000
# 1       20000
# 2       17000
# 3       10000
# 4        7500
#         ...
# 4741    15000
# 4742    29000
# 4743    35000
# 4744    45000
# 4745    15000
# Name: Rent, Length: 4746, dtype: int64

# %%
scaler = StandardScaler()
# encoder = LabelEncoder()
X_label = x.copy()

label_Encoders = {}
num_columns = x.select_dtypes(include=['int32', 'int64', 'float64']).columns
cat_columns = ['Area Type','Floor', 'Area Locality', 'City', 'Furnishing Status',
     'Tenant Preferred', 'Point of Contact']
# cat_columns
for col in cat_columns:
    encoder = LabelEncoder()
    X_label[col] = encoder.fit_transform(X_label[col])
    label_Encoders = encoder
X_label[num_columns] = scaler.fit_transform(X_label[num_columns])
X_label
# pd.DataFrame(X_scaled)
# X_encoded = pd.get_dummies(x,columns = ['Area Type','Floor', 'Area Locality', 'City', 'Furnishing Status',
#      'Tenant Preferred', 'Point of Contact'] ,drop_first=True)
# # X_encoded[num_columns] = scaler.fit_transform(X_encoded[num_columns])
# # X_encoded = X_encoded.astype(int)
# # # X_encodedp
# print(X_label.shape , X_encoded.shape)
# # X_test = pd.get_dummies(X_label, drop_first=True)

# X_train, X_test = X_train.align(X_test, axis=1, fill_value=0)

# X_train.head()
# Out:
#            BHK      Size  Floor  Area Type  Area Locality  City  \
# 0    -0.100773  0.208960    455          2            221     4
# 1    -0.100773 -0.264125     14          2           1527     4
# 2    -0.100773  0.051265     14          2           1760     4
# 3    -0.100773 -0.264125     10          2            526     4
# 4    -0.100773 -0.185277     10          1           1890     4
# ...        ...       ...    ...        ...            ...   ...
# 4741 -0.100773  0.051265    271          1            219     3
# 4742  1.100907  1.628216     16          2           1214     3
# 4743  1.100907  1.233978    271          1            724     3
# 4744  1.100907  0.839741    226          1            590     3
# 4745 -0.100773  0.051265    313          1           1915     3
#
#       Furnishing Status  Tenant Preferred  Bathroom  Point of Contact
# 0                     2                 1  0.038594                 2
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_label, y,
    test_size=0.2,      
    random_state=42
)

# %%
rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=42)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=300, n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)
y_pred
# Out:
# array([ 19007.33333333,  15762.84666667,  27974.33333333,  54298.91333333,
#        100643.33333333,  18664.33333333,  47863.58      ,  15076.66666667,
#        320066.66666667,  12758.00333333,  13135.33333333,  12059.67      ,
#         19095.54761905,  14774.66666667,  21366.66666667,  25776.33333333,
#        109300.        ,   8880.61333333,  15629.31      ,  61346.66666667,
#         29893.33333333,   7373.        ,  39706.66333333,  15015.        ,
#        137413.33333333,   7306.66666667,  11128.33333333,  27065.        ,
#          9944.        ,  13547.5       ,   6038.33333333,   7580.        ,
#         10303.77777778,  12945.66666667,  18644.        ,  26266.66666667,
#          7827.33333333,   7953.55555556,  14763.        ,   7435.5       ,
#         12471.66666667, 389666.66666667,  20027.        ,   7243.        ,
#         50127.        ,  11192.84666667,  40331.71333333,  79113.66666667,
# ...

# %%
print("R2:", r2_score(y_pred,y_test))
print("MAE:", mean_absolute_error(y_test, y_pred))
r2 = r2_score(y_test,y_pred)
r2
# Out:
# R2: 0.41906387217679886
# MAE: 13222.60265730994
# 0.49665697179819357

# %%
y_test
